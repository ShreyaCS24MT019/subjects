# %% [markdown]
# loading and uploding the dataset cifar -10

# %% [markdown]
# implementing 2-d netwokrs

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values (0 to 1)
x_train, x_test = x_train / 255.0, x_test / 255.0

# Convert labels to one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Print dataset shapes
print(f"Training data shape: {x_train.shape}, Training labels shape: {y_train.shape}")
print(f"Test data shape: {x_test.shape}, Test labels shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Training data shape: (50000, 32, 32, 3), Training labels shape: (50000, 10)
# Test data shape: (10000, 32, 32, 3), Test labels shape: (10000, 10)

# %%
# Define the FFNN model
model = Sequential([
    Flatten(input_shape=(32, 32, 3)),  # Flatten the images
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')    # Output layer (10 classes)
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         786,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 820,874 (3.13 MB)
#  Trainable params: 820,874 (3.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_test, y_test))
# Evaluate on test data
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.2800 - loss: 1.9861 - val_accuracy: 0.3831 - val_loss: 1.7285
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3834 - loss: 1.7139 - val_accuracy: 0.4106 - val_loss: 1.6317
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4209 - loss: 1.6169 - val_accuracy: 0.4348 - val_loss: 1.5865
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4379 - loss: 1.5621 - val_accuracy: 0.4445 - val_loss: 1.5636
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4640 - loss: 1.5115 - val_accuracy: 0.4514 - val_loss: 1.5248
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4691 - loss: 1.4862 - val_accuracy: 0.4609 - val_loss: 1.5027
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4796 - loss: 1.4583 - val_accuracy: 0.4663 - val_loss: 1.4879
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4929 - loss: 1.4327 - val_accuracy: 0.4729 - val_loss: 1.4773
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4962 - loss: 1.4038 - val_accuracy: 0.4566 - val_loss: 1.5238
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5055 - loss: 1.4013 - val_accuracy: 0.4744 - val_loss: 1.4864
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5056 - loss: 1.3788 - val_accuracy: 0.4884 - val_loss: 1.4350
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5195 - loss: 1.3513 - val_accuracy: 0.4854 - val_loss: 1.4440
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5268 - loss: 1.3364 - val_accuracy: 0.4926 - val_loss: 1.4182
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5235 - loss: 1.3287 - val_accuracy: 0.4880 - val_loss: 1.4344
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5351 - loss: 1.3030 - val_accuracy: 0.4931 - val_loss: 1.4309
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5376 - loss: 1.3057 - val_accuracy: 0.4945 - val_loss: 1.4297
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5433 - loss: 1.2834 - val_accuracy: 0.4777 - val_loss: 1.4860
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5414 - loss: 1.2862 - val_accuracy: 0.5057 - val_loss: 1.4136
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5513 - loss: 1.2636 - val_accuracy: 0.5043 - val_loss: 1.4011
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5579 - loss: 1.2400 - val_accuracy: 0.4656 - val_loss: 1.4681
# 313/313 - 1s - 2ms/step - accuracy: 0.4656 - loss: 1.4681
# Test Accuracy: 46.56%

# %% [markdown]
# trying it with different layers 3  layers

# %%
# Define the FFNN model
model = Sequential([
    Flatten(input_shape=(32, 32, 3)),  # Flatten the images
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(128,activation = 'relu'),
    Dense(10, activation='softmax')    # Output layer (10 classes)
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)                  │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │         786,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 837,386 (3.19 MB)
#  Trainable params: 837,386 (3.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history3 = model.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_test, y_test))
# Evaluate on test data
test_loss3, test_acc3 = model.evaluate(x_test, y_test, verbose=2)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.2765 - loss: 1.9874 - val_accuracy: 0.3863 - val_loss: 1.6862
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3952 - loss: 1.6834 - val_accuracy: 0.4343 - val_loss: 1.5905
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4255 - loss: 1.6071 - val_accuracy: 0.4124 - val_loss: 1.6282
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4415 - loss: 1.5554 - val_accuracy: 0.4403 - val_loss: 1.5604
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4598 - loss: 1.5072 - val_accuracy: 0.4561 - val_loss: 1.5271
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4713 - loss: 1.4677 - val_accuracy: 0.4645 - val_loss: 1.5053
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4850 - loss: 1.4389 - val_accuracy: 0.4700 - val_loss: 1.4826
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4918 - loss: 1.4242 - val_accuracy: 0.4809 - val_loss: 1.4487
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5098 - loss: 1.3818 - val_accuracy: 0.4511 - val_loss: 1.5348
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5086 - loss: 1.3787 - val_accuracy: 0.4905 - val_loss: 1.4398
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5198 - loss: 1.3383 - val_accuracy: 0.4770 - val_loss: 1.4570
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5277 - loss: 1.3262 - val_accuracy: 0.4899 - val_loss: 1.4326
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5315 - loss: 1.3142 - val_accuracy: 0.5086 - val_loss: 1.4011
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5393 - loss: 1.2844 - val_accuracy: 0.5050 - val_loss: 1.4262
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5484 - loss: 1.2684 - val_accuracy: 0.5069 - val_loss: 1.4077
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5468 - loss: 1.2654 - val_accuracy: 0.4927 - val_loss: 1.4632
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5551 - loss: 1.2407 - val_accuracy: 0.4908 - val_loss: 1.4604
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5627 - loss: 1.2251 - val_accuracy: 0.4978 - val_loss: 1.4437
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5640 - loss: 1.2071 - val_accuracy: 0.5065 - val_loss: 1.4257
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5720 - loss: 1.1938 - val_accuracy: 0.5091 - val_loss: 1.4178
# 313/313 - 1s - 3ms/step - accuracy: 0.5091 - loss: 1.4178
# Test Accuracy: 46.56%

# %% [markdown]
# now trying it with 5layers

# %%
# Define the FFNN model
model = Sequential([
    Flatten(input_shape=(32, 32, 3)),  # Flatten the images
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64,activation = 'relu'),
    Dense(32,activation='relu'),
    Dense(32,activation='relu'),
    Dense(10, activation='softmax')    # Output layer (10 classes)
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)                  │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 256)                 │         786,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 831,306 (3.17 MB)
#  Trainable params: 831,306 (3.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history5 = model.fit(x_train, y_train, epochs=15, batch_size=64, validation_data=(x_test, y_test))
# Evaluate on test data
test_loss5, test_acc5 = model.evaluate(x_test, y_test, verbose=2)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.2244 - loss: 2.0825 - val_accuracy: 0.3119 - val_loss: 1.8830
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.3576 - loss: 1.7705 - val_accuracy: 0.3966 - val_loss: 1.6781
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.3988 - loss: 1.6822 - val_accuracy: 0.4051 - val_loss: 1.6483
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4216 - loss: 1.6100 - val_accuracy: 0.4366 - val_loss: 1.5735
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4398 - loss: 1.5688 - val_accuracy: 0.4496 - val_loss: 1.5663
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4539 - loss: 1.5329 - val_accuracy: 0.4517 - val_loss: 1.5284
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4630 - loss: 1.4921 - val_accuracy: 0.4533 - val_loss: 1.5315
# Epoch 8/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4766 - loss: 1.4580 - val_accuracy: 0.4799 - val_loss: 1.4748
# Epoch 9/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4805 - loss: 1.4428 - val_accuracy: 0.4729 - val_loss: 1.4868
# Epoch 10/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4929 - loss: 1.4194 - val_accuracy: 0.4843 - val_loss: 1.4667
# Epoch 11/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4952 - loss: 1.4063 - val_accuracy: 0.4807 - val_loss: 1.4546
# Epoch 12/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5016 - loss: 1.3939 - val_accuracy: 0.4746 - val_loss: 1.4705
# Epoch 13/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5138 - loss: 1.3670 - val_accuracy: 0.4821 - val_loss: 1.4743
# Epoch 14/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5147 - loss: 1.3557 - val_accuracy: 0.4894 - val_loss: 1.4376
# Epoch 15/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5219 - loss: 1.3447 - val_accuracy: 0.4887 - val_loss: 1.4646
# 313/313 - 1s - 4ms/step - accuracy: 0.4887 - loss: 1.4646
# Test Accuracy: 46.56%

# %% [markdown]
# MINI TASK - 2 (TRYING IT WITH DIFFERENT ACTIVATION FUNCTION)

# %% [markdown]
# 1.Sigmoid

# %%
# Define the FFNN model
model = Sequential([
    Flatten(input_shape=(32, 32, 3)),  # Flatten the images
    Dense(256, activation='sigmoid'),
    Dense(128, activation='sigmoid'),
    Dense(64,activation = 'sigmoid'),
    Dense(10, activation='softmax')    # Output layer (10 classes)
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_3 (Flatten)                  │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 256)                 │         786,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 828,490 (3.16 MB)
#  Trainable params: 828,490 (3.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history_sigmoid = model.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_test, y_test))
# Evaluate on test data
test_loss_s, test_acc_s = model.evaluate(x_test, y_test, verbose=2)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.2154 - loss: 2.0975 - val_accuracy: 0.3334 - val_loss: 1.8290
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3399 - loss: 1.8151 - val_accuracy: 0.3753 - val_loss: 1.7394
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3696 - loss: 1.7395 - val_accuracy: 0.3881 - val_loss: 1.6990
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.3872 - loss: 1.6947 - val_accuracy: 0.3795 - val_loss: 1.7065
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.3995 - loss: 1.6603 - val_accuracy: 0.3849 - val_loss: 1.7264
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4107 - loss: 1.6294 - val_accuracy: 0.4162 - val_loss: 1.6122
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4276 - loss: 1.5939 - val_accuracy: 0.3976 - val_loss: 1.6515
# Epoch 8/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4319 - loss: 1.5759 - val_accuracy: 0.4323 - val_loss: 1.5836
# Epoch 9/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4396 - loss: 1.5605 - val_accuracy: 0.4441 - val_loss: 1.5544
# Epoch 10/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4495 - loss: 1.5348 - val_accuracy: 0.4371 - val_loss: 1.5653
# Epoch 11/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4516 - loss: 1.5166 - val_accuracy: 0.4353 - val_loss: 1.5694
# Epoch 12/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4627 - loss: 1.5010 - val_accuracy: 0.4486 - val_loss: 1.5424
# Epoch 13/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4638 - loss: 1.4938 - val_accuracy: 0.4532 - val_loss: 1.5296
# Epoch 14/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4648 - loss: 1.4766 - val_accuracy: 0.4611 - val_loss: 1.5260
# Epoch 15/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4741 - loss: 1.4628 - val_accuracy: 0.4399 - val_loss: 1.5489
# 313/313 - 1s - 3ms/step - accuracy: 0.4399 - loss: 1.5489
# Test Accuracy: 46.56%

# %% [markdown]
# TanH

# %%
# Define the FFNN model
model = Sequential([
    Flatten(input_shape=(32, 32, 3)),  # Flatten the images
    Dense(256, activation='tanh'),
    Dense(128, activation='tanh'),
    Dense(64,activation = 'tanh'),
    Dense(10, activation='softmax')    # Output layer (10 classes)
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_4 (Flatten)                  │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 256)                 │         786,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 828,490 (3.16 MB)
#  Trainable params: 828,490 (3.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history_t = model.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_test, y_test))
# Evaluate on test data
test_loss_t, test_acc_t = model.evaluate(x_test, y_test, verbose=2)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.2433 - loss: 2.0471 - val_accuracy: 0.3334 - val_loss: 1.8298
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.3247 - loss: 1.8431 - val_accuracy: 0.3142 - val_loss: 1.9169
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3465 - loss: 1.7987 - val_accuracy: 0.3672 - val_loss: 1.7564
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3565 - loss: 1.7759 - val_accuracy: 0.3533 - val_loss: 1.7691
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.3682 - loss: 1.7570 - val_accuracy: 0.3740 - val_loss: 1.7553
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3741 - loss: 1.7390 - val_accuracy: 0.3886 - val_loss: 1.6990
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3782 - loss: 1.7268 - val_accuracy: 0.3822 - val_loss: 1.7208
# Epoch 8/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3862 - loss: 1.7013 - val_accuracy: 0.3787 - val_loss: 1.7149
# Epoch 9/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3942 - loss: 1.6786 - val_accuracy: 0.3696 - val_loss: 1.7335
# Epoch 10/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3920 - loss: 1.6920 - val_accuracy: 0.3923 - val_loss: 1.6963
# Epoch 11/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3924 - loss: 1.6837 - val_accuracy: 0.4066 - val_loss: 1.6707
# Epoch 12/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3972 - loss: 1.6729 - val_accuracy: 0.3902 - val_loss: 1.6831
# Epoch 13/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4036 - loss: 1.6618 - val_accuracy: 0.3810 - val_loss: 1.7009
# Epoch 14/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4053 - loss: 1.6573 - val_accuracy: 0.4112 - val_loss: 1.6303
# Epoch 15/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4115 - loss: 1.6399 - val_accuracy: 0.4153 - val_loss: 1.6369
# 313/313 - 1s - 4ms/step - accuracy: 0.4153 - loss: 1.6369
# Test Accuracy: 46.56%

# %% [markdown]
# TASK - 2 (Implement a Basic CNN for CIFAR-10)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# Build the CNN model
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])
cnn_model.summary()
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_history = cnn_model.fit(x_train, y_train, epochs=20, batch_size=64, validation_split=0.2)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"CNN Test accuracy: {cnn_accuracy:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 32)                  │          73,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,538 (369.29 KB)
#  Trainable params: 94,538 (369.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.3013 - loss: 1.8917 - val_accuracy: 0.4778 - val_loss: 1.4403
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.5047 - loss: 1.3712 - val_accuracy: 0.5601 - val_loss: 1.2373
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5726 - loss: 1.1995 - val_accuracy: 0.5739 - val_loss: 1.1890
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.6139 - loss: 1.0774 - val_accuracy: 0.6294 - val_loss: 1.0675
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6467 - loss: 1.0050 - val_accuracy: 0.6495 - val_loss: 1.0179
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.6700 - loss: 0.9434 - val_accuracy: 0.6409 - val_loss: 1.0220
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6864 - loss: 0.8950 - val_accuracy: 0.6639 - val_loss: 0.9655
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6999 - loss: 0.8551 - val_accuracy: 0.6690 - val_loss: 0.9543
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7207 - loss: 0.7988 - val_accuracy: 0.6715 - val_loss: 0.9689
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7316 - loss: 0.7776 - val_accuracy: 0.6782 - val_loss: 0.9442
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7421 - loss: 0.7353 - val_accuracy: 0.6766 - val_loss: 0.9544
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7529 - loss: 0.7063 - val_accuracy: 0.6759 - val_loss: 0.9702
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7589 - loss: 0.6877 - val_accuracy: 0.6795 - val_loss: 0.9587
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7716 - loss: 0.6546 - val_accuracy: 0.6838 - val_loss: 0.9387
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7830 - loss: 0.6239 - val_accuracy: 0.6878 - val_loss: 0.9645
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7875 - loss: 0.6118 - val_accuracy: 0.6781 - val_loss: 0.9896
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7950 - loss: 0.5890 - val_accuracy: 0.6810 - val_loss: 0.9813
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7996 - loss: 0.5702 - val_accuracy: 0.6754 - val_loss: 1.0249
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8060 - loss: 0.5537 - val_accuracy: 0.6919 - val_loss: 0.9704
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8130 - loss: 0.5286 - val_accuracy: 0.6803 - val_loss: 1.0224
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6775 - loss: 1.0465
# CNN Test accuracy: 0.6807

# %% [markdown]
# MINI TASK 3 (instead of max pooling do average pooling)

# %%
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential

# Build the CNN model with Average Pooling
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    AveragePooling2D((2, 2)),  # Replaced MaxPooling2D with AveragePooling2D
    Conv2D(64, (3, 3), activation='relu'),
    AveragePooling2D((2, 2)),  # Replaced MaxPooling2D with AveragePooling2D
    Flatten(),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_history = cnn_model.fit(x_train, y_train, epochs=20, batch_size=64, validation_split=0.2)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"CNN Test accuracy: {cnn_accuracy:.4f}")
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d (AveragePooling2D) │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_1                  │ (None, 6, 6, 64)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 32)                  │          73,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,538 (369.29 KB)
#  Trainable params: 94,538 (369.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.2841 - loss: 1.9093 - val_accuracy: 0.4628 - val_loss: 1.4823
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4768 - loss: 1.4305 - val_accuracy: 0.5305 - val_loss: 1.3215
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.5317 - loss: 1.2960 - val_accuracy: 0.5494 - val_loss: 1.2503
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.5737 - loss: 1.1934 - val_accuracy: 0.5737 - val_loss: 1.2015
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.6026 - loss: 1.1190 - val_accuracy: 0.6064 - val_loss: 1.1236
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6168 - loss: 1.0750 - val_accuracy: 0.6140 - val_loss: 1.1153
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6421 - loss: 1.0068 - val_accuracy: 0.6325 - val_loss: 1.0560
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.6578 - loss: 0.9756 - val_accuracy: 0.6404 - val_loss: 1.0338
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6781 - loss: 0.9185 - val_accuracy: 0.6452 - val_loss: 1.0273
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6855 - loss: 0.8979 - val_accuracy: 0.6487 - val_loss: 1.0224
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.6973 - loss: 0.8651 - val_accuracy: 0.6576 - val_loss: 1.0024
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7107 - loss: 0.8297 - val_accuracy: 0.6715 - val_loss: 0.9536
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7183 - loss: 0.8088 - val_accuracy: 0.6727 - val_loss: 0.9553
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7336 - loss: 0.7693 - val_accuracy: 0.6686 - val_loss: 0.9675
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7370 - loss: 0.7567 - val_accuracy: 0.6726 - val_loss: 0.9641
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7479 - loss: 0.7296 - val_accuracy: 0.6723 - val_loss: 0.9763
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7543 - loss: 0.7119 - val_accuracy: 0.6886 - val_loss: 0.9379
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7609 - loss: 0.6863 - val_accuracy: 0.6805 - val_loss: 0.9718
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7690 - loss: 0.6689 - val_accuracy: 0.6914 - val_loss: 0.9522
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7772 - loss: 0.6452 - val_accuracy: 0.6882 - val_loss: 0.9627
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6837 - loss: 0.9714
# CNN Test accuracy: 0.6795

# %% [markdown]
# MINI TASK - 4(change in the kernel size and observe the difference)

# %% [markdown]
# chnaging into 3*3 kernel size

# %%
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential

# Build the CNN model with Average Pooling
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    AveragePooling2D((2, 2)),  # Replaced MaxPooling2D with AveragePooling2D
    Conv2D(64, (3, 3), activation='relu'),
    AveragePooling2D((2, 2)),  # Replaced MaxPooling2D with AveragePooling2D
    Flatten(),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax') ###yehh galat haib hai pooling nhi
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_history = cnn_model.fit(x_train, y_train, epochs=20, batch_size=64, validation_split=0.2)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"CNN Test accuracy: {cnn_accuracy:.4f}")
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_2                  │ (None, 15, 15, 32)          │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_3                  │ (None, 6, 6, 64)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_7 (Flatten)                  │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 32)                  │          73,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,538 (369.29 KB)
#  Trainable params: 94,538 (369.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.2794 - loss: 1.9533 - val_accuracy: 0.4511 - val_loss: 1.5001
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4647 - loss: 1.4714 - val_accuracy: 0.5063 - val_loss: 1.3694
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5219 - loss: 1.3247 - val_accuracy: 0.5382 - val_loss: 1.3131
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.5584 - loss: 1.2422 - val_accuracy: 0.5655 - val_loss: 1.2220
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5869 - loss: 1.1596 - val_accuracy: 0.6048 - val_loss: 1.1503
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6194 - loss: 1.0819 - val_accuracy: 0.6061 - val_loss: 1.1224
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6380 - loss: 1.0292 - val_accuracy: 0.6346 - val_loss: 1.0502
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.6529 - loss: 0.9810 - val_accuracy: 0.6365 - val_loss: 1.0700
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.6725 - loss: 0.9322 - val_accuracy: 0.6506 - val_loss: 1.0113
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6881 - loss: 0.8943 - val_accuracy: 0.6555 - val_loss: 0.9999
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6906 - loss: 0.8838 - val_accuracy: 0.6510 - val_loss: 1.0180
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7001 - loss: 0.8569 - val_accuracy: 0.6682 - val_loss: 0.9796
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7081 - loss: 0.8328 - val_accuracy: 0.6673 - val_loss: 0.9637
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7218 - loss: 0.7944 - val_accuracy: 0.6782 - val_loss: 0.9416
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7273 - loss: 0.7849 - val_accuracy: 0.6773 - val_loss: 0.9489
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7374 - loss: 0.7566 - val_accuracy: 0.6799 - val_loss: 0.9482
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7422 - loss: 0.7389 - val_accuracy: 0.6754 - val_loss: 0.9580
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7449 - loss: 0.7311 - val_accuracy: 0.6809 - val_loss: 0.9568
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7545 - loss: 0.7027 - val_accuracy: 0.6835 - val_loss: 0.9415
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7624 - loss: 0.6795 - val_accuracy: 0.6721 - val_loss: 0.9786
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6782 - loss: 0.9833
# CNN Test accuracy: 0.6723

# %% [markdown]
# changing the kernel size into 5*5
#
# > (5,5) shrinks too aggressively and causes tensor shape mismatches.

# %%
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential

# Build the CNN model with Average Pooling
cnn_model = Sequential([
    Conv2D(32, (5, 5), activation='relu', input_shape=(32, 32, 3)),
    AveragePooling2D((2, 2)),  # Replaced MaxPooling2D with AveragePooling2D
    Conv2D(64, (5, 5), activation='relu'),
    AveragePooling2D((2, 2)),  # Replaced MaxPooling2D with AveragePooling2D
    Flatten(),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_history = cnn_model.fit(x_train, y_train, epochs=20, batch_size=64, validation_split=0.2)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"CNN Test accuracy: {cnn_accuracy:.4f}")
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 28, 28, 32)          │           2,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_4                  │ (None, 14, 14, 32)          │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 10, 10, 64)          │          51,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_5                  │ (None, 5, 5, 64)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_8 (Flatten)                  │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_30 (Dense)                     │ (None, 32)                  │          51,232 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_31 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 106,314 (415.29 KB)
#  Trainable params: 106,314 (415.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.2712 - loss: 1.9460 - val_accuracy: 0.4435 - val_loss: 1.5100
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4694 - loss: 1.4535 - val_accuracy: 0.5175 - val_loss: 1.3634
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5363 - loss: 1.2949 - val_accuracy: 0.5552 - val_loss: 1.2410
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.5719 - loss: 1.1974 - val_accuracy: 0.5785 - val_loss: 1.1869
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5977 - loss: 1.1357 - val_accuracy: 0.5918 - val_loss: 1.1690
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6191 - loss: 1.0671 - val_accuracy: 0.5996 - val_loss: 1.1226
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6378 - loss: 1.0220 - val_accuracy: 0.6283 - val_loss: 1.0715
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6554 - loss: 0.9866 - val_accuracy: 0.6277 - val_loss: 1.0646
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6708 - loss: 0.9379 - val_accuracy: 0.6418 - val_loss: 1.0241
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6777 - loss: 0.9110 - val_accuracy: 0.6437 - val_loss: 1.0343
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6927 - loss: 0.8695 - val_accuracy: 0.6549 - val_loss: 0.9990
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6999 - loss: 0.8519 - val_accuracy: 0.6497 - val_loss: 1.0093
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7122 - loss: 0.8171 - val_accuracy: 0.6590 - val_loss: 0.9893
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7197 - loss: 0.7953 - val_accuracy: 0.6527 - val_loss: 1.0148
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7309 - loss: 0.7672 - val_accuracy: 0.6513 - val_loss: 1.0357
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7421 - loss: 0.7382 - val_accuracy: 0.6615 - val_loss: 1.0128
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7493 - loss: 0.7169 - val_accuracy: 0.6697 - val_loss: 0.9938
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7564 - loss: 0.6932 - val_accuracy: 0.6635 - val_loss: 1.0079
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7656 - loss: 0.6697 - val_accuracy: 0.6711 - val_loss: 0.9997
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7721 - loss: 0.6590 - val_accuracy: 0.6642 - val_loss: 1.0231
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6592 - loss: 1.0327
# CNN Test accuracy: 0.6515

# %% [markdown]
# so now on applying stride and padding properly

# %%
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential

# Build the CNN model with 5x5 pooling kernels
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3), strides=(2, 2), padding='same'),
    AveragePooling2D(pool_size=(2, 2)),  # Use strides=2 to avoid shrinking too fast
    Conv2D(64, (3, 3), activation='relu', strides=(2, 2), padding='same'),
    AveragePooling2D(pool_size=(2, 2)),  # Keep padding='same'
    Flatten(),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_history = cnn_model.fit(x_train, y_train, epochs=20, batch_size=64, validation_split=0.2)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"CNN Test accuracy: {cnn_accuracy:.4f}")
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 16, 16, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_6                  │ (None, 8, 8, 32)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 4, 4, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_7                  │ (None, 2, 2, 64)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_9 (Flatten)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_33 (Dense)                     │ (None, 32)                  │           8,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_34 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,002 (113.29 KB)
#  Trainable params: 29,002 (113.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.2458 - loss: 2.0447 - val_accuracy: 0.3677 - val_loss: 1.7300
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3909 - loss: 1.6592 - val_accuracy: 0.4012 - val_loss: 1.6331
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4361 - loss: 1.5416 - val_accuracy: 0.4285 - val_loss: 1.5441
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4611 - loss: 1.4659 - val_accuracy: 0.4904 - val_loss: 1.4135
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4900 - loss: 1.4015 - val_accuracy: 0.5004 - val_loss: 1.3863
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5017 - loss: 1.3664 - val_accuracy: 0.5151 - val_loss: 1.3392
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5213 - loss: 1.3223 - val_accuracy: 0.5056 - val_loss: 1.3696
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5337 - loss: 1.2985 - val_accuracy: 0.5346 - val_loss: 1.2862
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5509 - loss: 1.2450 - val_accuracy: 0.5411 - val_loss: 1.2576
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5608 - loss: 1.2189 - val_accuracy: 0.5512 - val_loss: 1.2335
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5668 - loss: 1.2003 - val_accuracy: 0.5539 - val_loss: 1.2340
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5788 - loss: 1.1741 - val_accuracy: 0.5647 - val_loss: 1.2076
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5852 - loss: 1.1423 - val_accuracy: 0.5781 - val_loss: 1.1735
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5936 - loss: 1.1264 - val_accuracy: 0.5739 - val_loss: 1.1753
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6010 - loss: 1.1040 - val_accuracy: 0.5862 - val_loss: 1.1588
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6118 - loss: 1.0796 - val_accuracy: 0.5970 - val_loss: 1.1246
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6207 - loss: 1.0543 - val_accuracy: 0.5884 - val_loss: 1.1427
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6224 - loss: 1.0556 - val_accuracy: 0.5969 - val_loss: 1.1113
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6269 - loss: 1.0320 - val_accuracy: 0.5996 - val_loss: 1.1159
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6293 - loss: 1.0283 - val_accuracy: 0.6041 - val_loss: 1.1011
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6174 - loss: 1.0992
# CNN Test accuracy: 0.6100

# %% [markdown]
# TASK 3 Improve CNN Using Stride and Padding

# %% [markdown]
# without any strides and padding

# %%
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential

# Build the CNN model with Average Pooling
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3),padding='same'),
    AveragePooling2D((2, 2)),  # Replaced MaxPooling2D with AveragePooling2D
    Conv2D(64, (3, 3), activation='relu', input_shape=(64,64,3),padding='same'),
    AveragePooling2D((2, 2)),  # Replaced MaxPooling2D with AveragePooling2D
    Flatten(),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_history = cnn_model.fit(x_train, y_train, epochs=30, batch_size=64, validation_split=0.2)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"CNN Test accuracy: {cnn_accuracy:.4f}")
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)                   │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_8                  │ (None, 16, 16, 32)          │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_9                  │ (None, 8, 8, 64)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_10 (Flatten)                 │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_36 (Dense)                     │ (None, 32)                  │         131,104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_37 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_38 (Dense)                     │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 151,882 (593.29 KB)
#  Trainable params: 151,882 (593.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.2992 - loss: 1.9169 - val_accuracy: 0.4737 - val_loss: 1.4398
# Epoch 2/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.5060 - loss: 1.3613 - val_accuracy: 0.5388 - val_loss: 1.2872
# Epoch 3/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5703 - loss: 1.1982 - val_accuracy: 0.5939 - val_loss: 1.1486
# Epoch 4/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6109 - loss: 1.0860 - val_accuracy: 0.6227 - val_loss: 1.0675
# Epoch 5/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6382 - loss: 1.0153 - val_accuracy: 0.6245 - val_loss: 1.0748
# Epoch 6/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6628 - loss: 0.9471 - val_accuracy: 0.6255 - val_loss: 1.0639
# Epoch 7/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.6844 - loss: 0.8914 - val_accuracy: 0.6483 - val_loss: 1.0036
# Epoch 8/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6963 - loss: 0.8549 - val_accuracy: 0.6626 - val_loss: 0.9568
# Epoch 9/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7114 - loss: 0.8117 - val_accuracy: 0.6769 - val_loss: 0.9333
# Epoch 10/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7212 - loss: 0.7935 - val_accuracy: 0.6831 - val_loss: 0.9190
# Epoch 11/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7364 - loss: 0.7489 - val_accuracy: 0.6844 - val_loss: 0.9079
# Epoch 12/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7474 - loss: 0.7218 - val_accuracy: 0.6805 - val_loss: 0.9316
# Epoch 13/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7564 - loss: 0.6869 - val_accuracy: 0.6944 - val_loss: 0.8990
# Epoch 14/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7676 - loss: 0.6666 - val_accuracy: 0.6861 - val_loss: 0.9057
# Epoch 15/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7758 - loss: 0.6424 - val_accuracy: 0.6893 - val_loss: 0.9139
# Epoch 16/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7833 - loss: 0.6127 - val_accuracy: 0.6922 - val_loss: 0.9298
# Epoch 17/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7892 - loss: 0.5975 - val_accuracy: 0.6881 - val_loss: 0.9476
# Epoch 18/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8014 - loss: 0.5640 - val_accuracy: 0.6998 - val_loss: 0.9174
# Epoch 19/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8068 - loss: 0.5490 - val_accuracy: 0.6956 - val_loss: 0.9332
# Epoch 20/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8162 - loss: 0.5212 - val_accuracy: 0.6972 - val_loss: 0.9438
# Epoch 21/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8276 - loss: 0.5024 - val_accuracy: 0.6873 - val_loss: 1.0014
# Epoch 22/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8274 - loss: 0.4884 - val_accuracy: 0.6943 - val_loss: 1.0274
# Epoch 23/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8377 - loss: 0.4657 - val_accuracy: 0.6963 - val_loss: 0.9752
# Epoch 24/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8441 - loss: 0.4453 - val_accuracy: 0.6899 - val_loss: 1.0287
# Epoch 25/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8468 - loss: 0.4335 - val_accuracy: 0.6933 - val_loss: 1.0474
# Epoch 26/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8565 - loss: 0.4062 - val_accuracy: 0.6910 - val_loss: 1.0544
# Epoch 27/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8608 - loss: 0.3921 - val_accuracy: 0.6976 - val_loss: 1.0555
# Epoch 28/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8707 - loss: 0.3682 - val_accuracy: 0.6882 - val_loss: 1.0935
# Epoch 29/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8742 - loss: 0.3594 - val_accuracy: 0.6974 - val_loss: 1.1207
# Epoch 30/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8800 - loss: 0.3423 - val_accuracy: 0.6888 - val_loss: 1.1670
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6880 - loss: 1.1793
# CNN Test accuracy: 0.6868

# %% [markdown]
# valid

# %%
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential

# Build the CNN model with Average Pooling
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3),padding='valid'),
    AveragePooling2D((2, 2)),  # Replaced MaxPooling2D with AveragePooling2D
    Conv2D(64, (3, 3), activation='relu', input_shape=(64,64,3),padding='valid'),
    AveragePooling2D((2, 2)),  # Replaced MaxPooling2D with AveragePooling2D
    Flatten(),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_history = cnn_model.fit(x_train, y_train, epochs=30, batch_size=64, validation_split=0.2)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"CNN Test accuracy: {cnn_accuracy:.4f}")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_2                  │ (None, 15, 15, 32)          │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_3                  │ (None, 6, 6, 64)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │          73,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,538 (369.29 KB)
#  Trainable params: 94,538 (369.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 45s 68ms/step - accuracy: 0.2709 - loss: 1.9552 - val_accuracy: 0.4583 - val_loss: 1.5101
# Epoch 2/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 65ms/step - accuracy: 0.4721 - loss: 1.4445 - val_accuracy: 0.5030 - val_loss: 1.3846
# Epoch 3/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 44s 70ms/step - accuracy: 0.5309 - loss: 1.3033 - val_accuracy: 0.5463 - val_loss: 1.2795
# Epoch 4/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 68ms/step - accuracy: 0.5619 - loss: 1.2100 - val_accuracy: 0.5577 - val_loss: 1.2278
# Epoch 5/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 67ms/step - accuracy: 0.6033 - loss: 1.1100 - val_accuracy: 0.6062 - val_loss: 1.1306
# Epoch 6/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 65ms/step - accuracy: 0.6210 - loss: 1.0653 - val_accuracy: 0.6159 - val_loss: 1.0797
# Epoch 7/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 46s 73ms/step - accuracy: 0.6438 - loss: 1.0078 - val_accuracy: 0.6309 - val_loss: 1.0523
# Epoch 8/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 65ms/step - accuracy: 0.6567 - loss: 0.9721 - val_accuracy: 0.6407 - val_loss: 1.0199
# Epoch 9/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 68ms/step - accuracy: 0.6718 - loss: 0.9337 - val_accuracy: 0.6525 - val_loss: 0.9980
# Epoch 10/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 67ms/step - accuracy: 0.6826 - loss: 0.9087 - val_accuracy: 0.6554 - val_loss: 0.9947
# Epoch 11/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 67ms/step - accuracy: 0.6946 - loss: 0.8764 - val_accuracy: 0.6513 - val_loss: 1.0116
# Epoch 12/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 67ms/step - accuracy: 0.7054 - loss: 0.8408 - val_accuracy: 0.6735 - val_loss: 0.9359
# Epoch 13/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 44s 71ms/step - accuracy: 0.7125 - loss: 0.8263 - val_accuracy: 0.6813 - val_loss: 0.9341
# Epoch 14/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 67ms/step - accuracy: 0.7234 - loss: 0.7897 - val_accuracy: 0.6828 - val_loss: 0.9311
# Epoch 15/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 69ms/step - accuracy: 0.7318 - loss: 0.7811 - val_accuracy: 0.6878 - val_loss: 0.9236
# Epoch 16/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 69ms/step - accuracy: 0.7353 - loss: 0.7607 - val_accuracy: 0.6854 - val_loss: 0.9242
# Epoch 17/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 66ms/step - accuracy: 0.7491 - loss: 0.7267 - val_accuracy: 0.6831 - val_loss: 0.9212
# Epoch 18/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 69ms/step - accuracy: 0.7500 - loss: 0.7218 - val_accuracy: 0.6867 - val_loss: 0.9255
# Epoch 19/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 69ms/step - accuracy: 0.7535 - loss: 0.7073 - val_accuracy: 0.6685 - val_loss: 0.9744
# Epoch 20/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 69ms/step - accuracy: 0.7582 - loss: 0.6935 - val_accuracy: 0.6861 - val_loss: 0.9270
# Epoch 21/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 65ms/step - accuracy: 0.7709 - loss: 0.6641 - val_accuracy: 0.6852 - val_loss: 0.9213
# Epoch 22/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 65ms/step - accuracy: 0.7712 - loss: 0.6579 - val_accuracy: 0.6906 - val_loss: 0.9388
# Epoch 23/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 65ms/step - accuracy: 0.7736 - loss: 0.6458 - val_accuracy: 0.6909 - val_loss: 0.9486
# Epoch 24/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 66ms/step - accuracy: 0.7849 - loss: 0.6145 - val_accuracy: 0.6957 - val_loss: 0.9269
# Epoch 25/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 65ms/step - accuracy: 0.7907 - loss: 0.6013 - val_accuracy: 0.6911 - val_loss: 0.9486
# Epoch 26/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 66ms/step - accuracy: 0.7897 - loss: 0.6002 - val_accuracy: 0.6965 - val_loss: 0.9306
# Epoch 27/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 66ms/step - accuracy: 0.8021 - loss: 0.5706 - val_accuracy: 0.6860 - val_loss: 0.9557
# Epoch 28/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 65ms/step - accuracy: 0.8068 - loss: 0.5611 - val_accuracy: 0.6881 - val_loss: 0.9539
# Epoch 29/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 69ms/step - accuracy: 0.8081 - loss: 0.5515 - val_accuracy: 0.6698 - val_loss: 1.0423
# Epoch 30/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 69ms/step - accuracy: 0.8080 - loss: 0.5502 - val_accuracy: 0.6856 - val_loss: 0.9960
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6909 - loss: 1.0076
# CNN Test accuracy: 0.6836

# %% [markdown]
# Now on applying proper padding and strides

# %% [markdown]
# 1. keeping the strides as 2 instead of 1

# %%
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential


cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3),strides=(2, 2)),
    AveragePooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu',input_shape = (64,64,3),strides=(2, 2)),
    AveragePooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_history = cnn_model.fit(x_train, y_train, epochs=30, batch_size=64, validation_split=0.2)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"CNN Test accuracy: {cnn_accuracy:.4f}")
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 15, 15, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_4                  │ (None, 7, 7, 32)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 3, 3, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_5                  │ (None, 1, 1, 64)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,858 (89.29 KB)
#  Trainable params: 22,858 (89.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.1949 - loss: 2.1200 - val_accuracy: 0.2906 - val_loss: 1.8898
# Epoch 2/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.3046 - loss: 1.8490 - val_accuracy: 0.3279 - val_loss: 1.7858
# Epoch 3/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.3442 - loss: 1.7510 - val_accuracy: 0.3697 - val_loss: 1.6908
# Epoch 4/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.3816 - loss: 1.6806 - val_accuracy: 0.3891 - val_loss: 1.6507
# Epoch 5/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.4023 - loss: 1.6220 - val_accuracy: 0.3900 - val_loss: 1.6170
# Epoch 6/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4131 - loss: 1.5870 - val_accuracy: 0.4102 - val_loss: 1.5842
# Epoch 7/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.4294 - loss: 1.5534 - val_accuracy: 0.4232 - val_loss: 1.5616
# Epoch 8/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.4490 - loss: 1.5130 - val_accuracy: 0.4376 - val_loss: 1.5290
# Epoch 9/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.4565 - loss: 1.4932 - val_accuracy: 0.4372 - val_loss: 1.5311
# Epoch 10/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.4597 - loss: 1.4825 - val_accuracy: 0.4478 - val_loss: 1.5000
# Epoch 11/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.4716 - loss: 1.4545 - val_accuracy: 0.4567 - val_loss: 1.5064
# Epoch 12/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.4820 - loss: 1.4340 - val_accuracy: 0.4638 - val_loss: 1.4732
# Epoch 13/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4769 - loss: 1.4263 - val_accuracy: 0.4797 - val_loss: 1.4364
# Epoch 14/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.4938 - loss: 1.4039 - val_accuracy: 0.4647 - val_loss: 1.4819
# Epoch 15/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.4909 - loss: 1.3977 - val_accuracy: 0.4766 - val_loss: 1.4332
# Epoch 16/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.5050 - loss: 1.3648 - val_accuracy: 0.4841 - val_loss: 1.4347
# Epoch 17/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5139 - loss: 1.3508 - val_accuracy: 0.4921 - val_loss: 1.4089
# Epoch 18/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5192 - loss: 1.3392 - val_accuracy: 0.4974 - val_loss: 1.4005
# Epoch 19/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5186 - loss: 1.3328 - val_accuracy: 0.4975 - val_loss: 1.3994
# Epoch 20/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5254 - loss: 1.3236 - val_accuracy: 0.4894 - val_loss: 1.4185
# Epoch 21/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5300 - loss: 1.3138 - val_accuracy: 0.5027 - val_loss: 1.3818
# Epoch 22/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.5333 - loss: 1.2920 - val_accuracy: 0.4931 - val_loss: 1.4205
# Epoch 23/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.5385 - loss: 1.2835 - val_accuracy: 0.4949 - val_loss: 1.3906
# Epoch 24/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5391 - loss: 1.2825 - val_accuracy: 0.4966 - val_loss: 1.3854
# Epoch 25/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.5464 - loss: 1.2690 - val_accuracy: 0.5083 - val_loss: 1.3678
# Epoch 26/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5511 - loss: 1.2499 - val_accuracy: 0.5154 - val_loss: 1.3541
# Epoch 27/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.5528 - loss: 1.2525 - val_accuracy: 0.5101 - val_loss: 1.3638
# Epoch 28/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5542 - loss: 1.2517 - val_accuracy: 0.5137 - val_loss: 1.3573
# Epoch 29/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5594 - loss: 1.2377 - val_accuracy: 0.5084 - val_loss: 1.3740
# Epoch 30/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.5568 - loss: 1.2319 - val_accuracy: 0.5027 - val_loss: 1.3678
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5198 - loss: 1.3519
# CNN Test accuracy: 0.5160

# %% [markdown]
# on changing padding to same and keeping strides to 1

# %%
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential


cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3),strides=(1, 1)),
    AveragePooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu',input_shape = (64,64,3),strides=(1, 1)),
    AveragePooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_history = cnn_model.fit(x_train, y_train, epochs=30, batch_size=64, validation_split=0.2)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"CNN Test accuracy: {cnn_accuracy:.4f}")
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_8                  │ (None, 15, 15, 32)          │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_9                  │ (None, 6, 6, 64)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 32)                  │          73,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,538 (369.29 KB)
#  Trainable params: 94,538 (369.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 75ms/step - accuracy: 0.2721 - loss: 1.9663 - val_accuracy: 0.4450 - val_loss: 1.5118
# Epoch 2/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 66ms/step - accuracy: 0.4794 - loss: 1.4436 - val_accuracy: 0.5212 - val_loss: 1.3517
# Epoch 3/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 67ms/step - accuracy: 0.5384 - loss: 1.2918 - val_accuracy: 0.5514 - val_loss: 1.2551
# Epoch 4/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 70ms/step - accuracy: 0.5747 - loss: 1.1973 - val_accuracy: 0.5907 - val_loss: 1.1609
# Epoch 5/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 69ms/step - accuracy: 0.6047 - loss: 1.1159 - val_accuracy: 0.5898 - val_loss: 1.1564
# Epoch 6/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 66ms/step - accuracy: 0.6312 - loss: 1.0483 - val_accuracy: 0.6249 - val_loss: 1.0904
# Epoch 7/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 66ms/step - accuracy: 0.6506 - loss: 0.9946 - val_accuracy: 0.6347 - val_loss: 1.0554
# Epoch 8/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 66ms/step - accuracy: 0.6676 - loss: 0.9513 - val_accuracy: 0.6500 - val_loss: 1.0063
# Epoch 9/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 70ms/step - accuracy: 0.6836 - loss: 0.9113 - val_accuracy: 0.6459 - val_loss: 1.0168
# Epoch 10/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 66ms/step - accuracy: 0.6953 - loss: 0.8756 - val_accuracy: 0.6723 - val_loss: 0.9573
# Epoch 11/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 69ms/step - accuracy: 0.7060 - loss: 0.8470 - val_accuracy: 0.6670 - val_loss: 0.9687
# Epoch 12/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 70ms/step - accuracy: 0.7151 - loss: 0.8215 - val_accuracy: 0.6603 - val_loss: 0.9807
# Epoch 13/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 69ms/step - accuracy: 0.7253 - loss: 0.7906 - val_accuracy: 0.6742 - val_loss: 0.9433
# Epoch 14/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 66ms/step - accuracy: 0.7294 - loss: 0.7871 - val_accuracy: 0.6818 - val_loss: 0.9288
# Epoch 15/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 69ms/step - accuracy: 0.7434 - loss: 0.7397 - val_accuracy: 0.6890 - val_loss: 0.8999
# Epoch 16/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 70ms/step - accuracy: 0.7496 - loss: 0.7231 - val_accuracy: 0.6917 - val_loss: 0.9097
# Epoch 17/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 67ms/step - accuracy: 0.7592 - loss: 0.6976 - val_accuracy: 0.6940 - val_loss: 0.9105
# Epoch 18/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 68ms/step - accuracy: 0.7617 - loss: 0.6780 - val_accuracy: 0.6920 - val_loss: 0.9161
# Epoch 19/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 67ms/step - accuracy: 0.7690 - loss: 0.6637 - val_accuracy: 0.6921 - val_loss: 0.9131
# Epoch 20/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 67ms/step - accuracy: 0.7770 - loss: 0.6432 - val_accuracy: 0.7041 - val_loss: 0.8946
# Epoch 21/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 44s 70ms/step - accuracy: 0.7765 - loss: 0.6300 - val_accuracy: 0.6994 - val_loss: 0.9144
# Epoch 22/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 68ms/step - accuracy: 0.7867 - loss: 0.6128 - val_accuracy: 0.6846 - val_loss: 0.9454
# Epoch 23/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 69ms/step - accuracy: 0.7848 - loss: 0.6064 - val_accuracy: 0.6969 - val_loss: 0.9324
# Epoch 24/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 66ms/step - accuracy: 0.7974 - loss: 0.5839 - val_accuracy: 0.6989 - val_loss: 0.9348
# Epoch 25/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 69ms/step - accuracy: 0.8034 - loss: 0.5626 - val_accuracy: 0.6964 - val_loss: 0.9262
# Epoch 26/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 70ms/step - accuracy: 0.8094 - loss: 0.5468 - val_accuracy: 0.6993 - val_loss: 0.9257
# Epoch 27/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 69ms/step - accuracy: 0.8174 - loss: 0.5342 - val_accuracy: 0.7010 - val_loss: 0.9418
# Epoch 28/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 70ms/step - accuracy: 0.8147 - loss: 0.5222 - val_accuracy: 0.6962 - val_loss: 0.9522
# Epoch 29/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 69ms/step - accuracy: 0.8256 - loss: 0.5011 - val_accuracy: 0.6990 - val_loss: 0.9738
# Epoch 30/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 69ms/step - accuracy: 0.8264 - loss: 0.4936 - val_accuracy: 0.6950 - val_loss: 1.0002
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6993 - loss: 1.0082
# CNN Test accuracy: 0.6921

# %% [markdown]
# Feature map display while applying the strides and padding properly

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Input

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize the dataset
x_train, x_test = x_train / 255.0, x_test / 255.0

# Select one image for visualization
sample_image = x_train[0]
sample_image = np.expand_dims(sample_image, axis=0)  # Add batch dimension

# Display the original image
plt.imshow(x_train[0])
plt.title("Original Image")
plt.axis("off")
plt.show()

# Define CNN Model for Feature Map Extraction
input_layer = Input(shape=(32, 32, 3))

# Conv layer with stride=1 and padding='valid'
conv_stride_1_valid = Conv2D(32, (5, 5), strides=1, padding='valid', activation='relu')(input_layer)
pooling_1 = AveragePooling2D((2, 2))(conv_stride_1_valid)

# Conv layer with stride=2 and padding='same'
conv_stride_2_same = Conv2D(64, (5, 5), strides=2, padding='same', activation='relu')(pooling_1)
pooling_2 = AveragePooling2D((2, 2))(conv_stride_2_same)

# Define models to extract feature maps
model_stride_1_valid = Model(inputs=input_layer, outputs=conv_stride_1_valid)
model_stride_2_same = Model(inputs=input_layer, outputs=conv_stride_2_same)

# Get feature maps
feature_maps_stride_1_valid = model_stride_1_valid.predict(sample_image)
feature_maps_stride_2_same = model_stride_2_same.predict(sample_image)

# Function to visualize feature maps
def plot_feature_maps(feature_maps, title):
    num_filters = feature_maps.shape[-1]
    fig, axes = plt.subplots(1, min(num_filters, 8), figsize=(15, 5))  # Show max 8 feature maps
    fig.suptitle(title)

    for i in range(min(num_filters, 8)):  # Limit visualization to 8 filters
        axes[i].imshow(feature_maps[0, :, :, i], cmap='viridis')
        axes[i].axis("off")

    plt.show()

# Plot feature maps before and after stride/padding changes
plot_feature_maps(feature_maps_stride_1_valid, "Feature Maps (Stride=1, Padding='Valid')")
plot_feature_maps(feature_maps_stride_2_same, "Feature Maps (Stride=2, Padding='Same')")

# %% [markdown]
# TASK - 4 Enhance CNN Model with Regularization

# %% [markdown]
# Without drop out

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2

# Build the CNN model with regularization techniques
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001), input_shape=(32, 32, 3)),
    BatchNormalization(),
    AveragePooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    AveragePooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.0),
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.0),
    Dense(10, activation='softmax')
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model without data augmentation
cnn_history = cnn_model.fit(
    x_train, y_train, batch_size=64, epochs=25, validation_data=(x_test, y_test)
)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"New CNN Test Accuracy: {cnn_accuracy:.4f}")

# %% [markdown]
# with dropout

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Apply Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Build the CNN model with regularization techniques
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001), input_shape=(32, 32, 3)),
    BatchNormalization(),
    AveragePooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    AveragePooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.5),  # Drop 50% of neurons to prevent overfitting
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.3),  # Drop 30% of neurons
    Dense(10, activation='softmax')  # Output layer
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model with data augmentation
cnn_history = cnn_model.fit(
    datagen.flow(x_train, y_train, batch_size=64),
    epochs=25,
    validation_data=(x_test, y_test)
)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"New CNN Test Accuracy: {cnn_accuracy:.4f}")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 30, 30, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_2                  │ (None, 15, 15, 32)          │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 13, 13, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_3                  │ (None, 6, 6, 64)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │         147,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 169,706 (662.91 KB)
#  Trainable params: 169,514 (662.16 KB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/25
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 99s 122ms/step - accuracy: 0.2325 - loss: 2.3804 - val_accuracy: 0.4208 - val_loss: 1.7774
# Epoch 2/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.3872 - loss: 1.8378 - val_accuracy: 0.3149 - val_loss: 2.2497
# Epoch 3/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 144s 118ms/step - accuracy: 0.4614 - loss: 1.6583 - val_accuracy: 0.5110 - val_loss: 1.6207
# Epoch 4/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.4962 - loss: 1.5777 - val_accuracy: 0.5359 - val_loss: 1.4396
# Epoch 5/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 98s 125ms/step - accuracy: 0.5130 - loss: 1.5364 - val_accuracy: 0.5908 - val_loss: 1.3077
# Epoch 6/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 101s 130ms/step - accuracy: 0.5270 - loss: 1.5150 - val_accuracy: 0.6166 - val_loss: 1.2841
# Epoch 7/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.5445 - loss: 1.4896 - val_accuracy: 0.5935 - val_loss: 1.3494
# Epoch 8/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.5574 - loss: 1.4622 - val_accuracy: 0.6016 - val_loss: 1.3092
# Epoch 9/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.5719 - loss: 1.4469 - val_accuracy: 0.6079 - val_loss: 1.3293
# Epoch 10/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.5722 - loss: 1.4369 - val_accuracy: 0.6458 - val_loss: 1.2180
# Epoch 11/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.5808 - loss: 1.4252 - val_accuracy: 0.6492 - val_loss: 1.2095
# Epoch 12/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 142s 119ms/step - accuracy: 0.5822 - loss: 1.4184 - val_accuracy: 0.6542 - val_loss: 1.2259
# Epoch 13/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.5880 - loss: 1.4043 - val_accuracy: 0.6266 - val_loss: 1.2735
# Epoch 14/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.5913 - loss: 1.3973 - val_accuracy: 0.6269 - val_loss: 1.2933
# Epoch 15/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.5990 - loss: 1.3877 - val_accuracy: 0.6550 - val_loss: 1.2016
# Epoch 16/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.5983 - loss: 1.3838 - val_accuracy: 0.6518 - val_loss: 1.2157
# Epoch 17/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.6054 - loss: 1.3765 - val_accuracy: 0.6783 - val_loss: 1.1522
# Epoch 18/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.6038 - loss: 1.3824 - val_accuracy: 0.6276 - val_loss: 1.2681
# Epoch 19/25
# 686/782 ━━━━━━━━━━━━━━━━━━━━ 10s 113ms/step - accuracy: 0.6100 - loss: 1.3630

# %% [markdown]
# without augmentation

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator


# Build the CNN model with regularization techniques
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001), input_shape=(32, 32, 3)),
    BatchNormalization(),
    AveragePooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    AveragePooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.5),  # Drop 50% of neurons to prevent overfitting
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.3),  # Drop 30% of neurons
    Dense(10, activation='softmax')  # Output layer
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model with data augmentation
cnn_history = cnn_model.fit(
    datagen.flow(x_train, y_train, batch_size=64),
    epochs=25,
    validation_data=(x_test, y_test)
)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"New CNN Test Accuracy: {cnn_accuracy:.4f}")

# %% [markdown]
# with augmentation

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Apply Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Build the CNN model with regularization techniques
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001), input_shape=(32, 32, 3)),
    BatchNormalization(),
    AveragePooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    AveragePooling2D(pool_size=(2,2)),

    Flatten(),
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.5),  # Drop 50% of neurons to prevent overfitting
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.3),  # Drop 30% of neurons
    Dense(10, activation='softmax')  # Output layer
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model with data augmentation
cnn_history = cnn_model.fit(
    datagen.flow(x_train, y_train, batch_size=64),
    epochs=25,
    validation_data=(x_test, y_test)
)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"New CNN Test Accuracy: {cnn_accuracy:.4f}")

# %% [markdown]
# applying both augmentation and dropout

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Apply Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Build the CNN model with regularization techniques
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001), input_shape=(32, 32, 3)),
    BatchNormalization(),
    AveragePooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    AveragePooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.5),
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.3),  # Drop 30% of neurons
    Dense(10, activation='softmax')  # Output layer
])

# Print model summary
cnn_model.summary()

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model with data augmentation
cnn_history = cnn_model.fit(
    datagen.flow(x_train, y_train, batch_size=64),
    epochs=20,
    validation_data=(x_test, y_test)
)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test, y_test)
print(f"New CNN Test Accuracy: {cnn_accuracy:.4f}")
